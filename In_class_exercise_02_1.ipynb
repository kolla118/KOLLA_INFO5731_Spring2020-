# %% [markdown]
# <a href="https://colab.research.google.com/github/kolla118/KOLLA_INFO5731_Spring2020-/blob/main/In_class_exercise_02_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
Research question: How has Covid-19 impacted the car sales across the world?

The Covid-19 pandemic has impacted everyone on the earth both directly and indirectly, and still continues to do so. 
The pandemic has brought in many changes to the personal lifestyle choices of the people. By now, it is a well known fact that the virus spreads through air and surface contact, 
and can infect a person multiple times, but its impact on the internal organs of the human body is not known or thoroughly researched. 
Because of the uncertainity, there is a fear among those who opt for public transport for their daily commute about their safety.

The aim of the research is to find the impact of the Covid-19 on car sales, as answering this question can help to determine the general public's choice of 
daily commute amid the pandemic. And help determine the future of the public transport and determine whether to increase and decrease the production capacity 
of car manufacturing companies.

Data required for the research:
Year wise data of the past 15 years of the following:
i) Car sales
ii) Percentage change (indicating Growth or decline)
iii) Figures of (i) and (ii) of at least two nations across each continent.

Data collection and storing:
The data can be obtained from the websites using web scraping (from the websites which allow users to scrape their data). 
The website chosen for the collection of the data is "carsalesbase.com".
The data from the aforementioned website will be scrapped using "Beautiful Soup" HTML parser. 
The data once collected will be stored in pandas dataframe and then will be saved in CSV format for further analysis.

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup


car_model=[]
car_year=[]
Jan=[]
Feb=[]
Mar=[]
Apr=[]
May=[]
Jun=[]
Jul=[]
Aug=[]
Sep=[]
Oct=[]
Nov=[]
Dec=[]
year=''
for i in range(2019,2022):
    year=str(i)
    search_text='https://www.goodcarbadcar.net/'+str(i)+'-us-vehicle-sales-figures-by-model/'
    req = requests.get(search_text)
    soup = BeautifulSoup(req.text, 'html.parser')
    for i in soup.find_all('tbody'):
        pass
    l=str(i).split('</tr>')
    for i in range(0,len(l)-1):
        l1=l[i].split('<td style="">')
        car_model.append(l1[1][:l1[1].find('</td>')])
        car_year.append(year)
        Jan.append(l1[2][:l1[2].find('</td>')])
        Feb.append(l1[3][:l1[3].find('</td>')])
        Mar.append(l1[4][:l1[4].find('</td>')])
        Apr.append(l1[5][:l1[5].find('</td>')])
        May.append(l1[6][:l1[6].find('</td>')])
        Jun.append(l1[7][:l1[7].find('</td>')])
        Jul.append(l1[8][:l1[8].find('</td>')])
        Aug.append(l1[9][:l1[9].find('</td>')])
        Sep.append(l1[10][:l1[10].find('</td>')])
        Oct.append(l1[11][:l1[11].find('</td>')])
        Nov.append(l1[12][:l1[12].find('</td>')])
        Dec.append(l1[13][:l1[13].find('</td>')])

df_display={'car_model':car_model,'Year':car_year,'Jan':Jan,'Feb':Feb,'Mar':Mar,'Apr':Apr,'May':May,'Jun':Jun,'Jul':Jul,'Aug':Aug,'Sep':Sep,'Oct':Oct,'Nov':Nov,'Dec':Dec}
df = pd.DataFrame(df_display)
print(df)
# Out:
#            car_model  Year    Jan    Feb  ...    Sep    Oct    Nov    Dec
# 0          Acura ILX  2019    805  1,047  ...  1,078  1,430  1,253  1,305
# 1          Acura MDX  2019  2,968  3,833  ...  3,833  4,368  4,784  5,636
# 2          Acura NSX  2019     31     22  ...     16     15     11     10
# 3          Acura RDX  2019  4,172  4,965  ...  4,384  5,888  5,767  6,263
# 4          Acura RLX  2019    119    127  ...     46     68     80     72
# ..               ...   ...    ...    ...  ...    ...    ...    ...    ...
# 910  Volvo 90-Series  2021    136    253  ...     77     70     85    147
# 911        Volvo C40  2021      0      0  ...      0      0      0     42
# 912       Volvo XC40  2021  1,756  1,886  ...  2,070  1,987  1,244  1,482
# 913       Volvo XC60  2021  2,196  2,757  ...  3,220  3,032  3,043  3,924
# 914       Volvo XC90  2021  2,492  2,674  ...  2,886  2,583  2,373  3,604
#
# [915 rows x 14 columns]

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

#Mentioning the header
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36'}
#Creating the required lists 
title = []
authors = []
abstract = []
def getresults(page, topic):
    link = f'https://scholar.google.com/scholar?start={page}&q={topic}&hl=en&as_sdt=0,5'
    #link = 'https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&as_ylo=2017&q=information+retrieval&btnG='
    req = requests.get(link, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    page = soup.select('div', {'class': 'gs_res_ccl_mid'})

    for i in page:
        search = {
        'title': i.find('h3', {'class': 'gs_rt'}).text,
        'authors': i.find('div', {'class': 'gs_a'}).text,
        'abstract': i.find('div', {'class': 'gs_rs'}).text
        }

        title.append(search[0])
        authors.append(search[1])
        abstract.append(search[2])
    return

for x in range(0,100):
  getresults(x, "insomnia")

df = pd.DataFrame()
df['title'] = title
df['authors year and journal'] = authors
df['abstract'] = abstract
df
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e1d16fb287bf> in <module>()
#      29
#      30 for x in range(0,100):
# ---> 31   getresults(x, "insomnia")
#      32
#      33 df = pd.DataFrame()
#
# <ipython-input-25-e1d16fb287bf> in getresults(page, topic)
#      14     req = requests.get(link, headers=headers)
#      15     soup = BeautifulSoup(req.text, 'html.parser')
# ---> 16     page = soup.select('div', {'class': 'gs_res_ccl_mid'})
#      17
#      18     for i in page:
#
# /usr/local/lib/python3.7/dist-packages/bs4/element.py in select(self, selector, _candidate_generator, limit)
#    1607                     print("    Running candidate generator on %s %s" % (
#    1608                         tag.name, repr(tag.attrs)))
# -> 1609                 for candidate in _use_candidate_generator(tag):
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import os
import tweepy as tw
import pandas as pd

key= '2Em7SxlX9jPMfL4x97r3zMO0x'
secret= 'sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd'
token= '1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT'
access_secret= 'oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF'

authorize = tw.OAuthHandler(key, secret)
authorize.set_access_token(token, access_secret)
api = tw.API(authorize, wait_on_rate_limit=True)

key_word = "#love"
required_date_from = "2021-12-01"

tweets = tw.Cursor(api.search,
              q=key_word,
              lang="en",
              since=required_date_from).items(1000)

[tweet.text for tweet in tweets]
# Out:
# ["“You spend your whole life stuck in the labyrinth, thinking about how you'll escape one day &amp; how awesome it will b… https://t.co/gsMU8vm1ak",
#  'RT @SunMusic: A hug is the best gift you can give..🤗❤️ Happy hug day \n\n#SunMusic #HitSongs #Kollywood #Tamil #Songs #Music #NonStopHits #Hu…',
#  'All set for a Valentines Day ♥️\nBut nowhere to go 🤯\n#om #love #sonalchauhan #gold #sunlight #sun #sunshine #morning… https://t.co/I6koapMU2N',
#  "Don't raise someone's hopes when you know the truth will destroy them. #love #TeamFollowBack",
#  "RT @LacavaBathroom: Here's an #optional #wood box for wall hung toilets! Pick from our standard wood finishes or select your #favorite #CUS…",
#  '#follow us and enjoy #rock #bluesrock #blues and the newest!\n\n#listen on https://t.co/q5bQfwme3A Stream… https://t.co/3hwEzllj0m',
#  'RT @cartoonnetwork: Who else is feeling single rn? 😭❤️\u200d🔥 A round up of our fave ship fan art!\n\n🎨 @Sourbeefio\n🎨 @_gabrielpicolo \n🎨 @CynDavil…',
# ...
